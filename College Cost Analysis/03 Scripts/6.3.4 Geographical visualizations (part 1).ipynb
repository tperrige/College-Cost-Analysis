# %% [markdown]
# ## Table of Contents
#
# ### 1. Importing libraries and data
# ### 2. Geospatial Analysis
# ##### 1. Number of higher cost institutions
# ##### 2. Average cost of attendance at public institutions
# ##### 3. Average cost of attendance at private institutions
# ##### 4. Average family income

# %% [markdown]
# # 01. Importing libraries and data

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os
import folium

# %%
# Ensure charts appear in notebook
# %matplotlib inline

# %%
# Define path variable
path = r'/Users/taraperrigeold/Documents/Documents - Tara Perrige’s MacBook Pro/CareerFoundry/College Cost Analysis'

# %%
# Check output
path
# Out:
# '/Users/taraperrigeold/Documents/Documents - Tara Perrige’s MacBook Pro/CareerFoundry/College Cost Analysis'

# %%
# Import json file
country_geo = os.path.join(path, '02 Data', 'Original Data', 'us-states.json')

# %%
# Check output
country_geo
# Out:
# '/Users/taraperrigeold/Documents/Documents - Tara Perrige’s MacBook Pro/CareerFoundry/College Cost Analysis/02 Data/Original Data/us-states.json'

# %%
# Import public institutions data set
public = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'public_data.pkl'))

# %%
# Check head
public.head()
# Out:
#    UNITID                                 NAME        CITY STATE         ZIP  \
# 0  100654             Alabama A & M University      Normal    AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham    AL  35294-0110
# 2  100706  University of Alabama in Huntsville  Huntsville    AL       35899
# 3  100724             Alabama State University  Montgomery    AL  36104-0271
# 4  100751            The University of Alabama  Tuscaloosa    AL  35487-0100
#
#    REGION  LOCALE  COSTT4_A  DEBT_MDN        FAMINC  ADM_RATE  SAT_AVG  \
# 0       5    12.0   22489.0   15500.0  32362.826114    0.8986    957.0
# 1       5    12.0   24347.0   15000.0  51306.674306    0.9211   1220.0
# 2       5    12.0   23441.0   14476.0  61096.588949    0.8087   1314.0
# 3       5    12.0   21476.0   18679.0  31684.382188    0.9774    972.0
# 4       5    12.0   29424.0   17500.0  91846.749624    0.5906   1252.0
#
#       UGDS  RET_FT4_POOLED  UGDS_WHITE COST_CATEGORY
# 0   4990.0          0.5978      0.0186   Higher cost
# 1  13186.0          0.8303      0.5717   Higher cost
# 2   7458.0          0.8269      0.7167   Higher cost
# 3   3903.0          0.5898      0.0167   Higher cost
# 4  32177.0          0.8748      0.7774   Higher cost

# %%
# Check shape
public.shape
# Out:
# (1449, 16)

# %%
# Import private, non-profit institutions data set - excluding outliers
private = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'private_data.pkl'))

# %%
# Check head
private.head()
# Out:
#    UNITID                           NAME        CITY STATE         ZIP  \
# 0  100937    Birmingham-Southern College  Birmingham    AL       35254
# 1  101189            Faulkner University  Montgomery    AL  36109-3390
# 2  101365  Herzing University-Birmingham  Birmingham    AL       35209
# 3  101435             Huntingdon College  Montgomery    AL  36106-2148
# 4  101541                 Judson College      Marion    AL       36756
#
#    REGION  LOCALE  COSTT4_A  NPT4_PRIV  DEBT_MDN        FAMINC  ADM_RATE  \
# 0       5    12.0   52176.0    25494.0   18500.0  86672.871041    0.5666
# 1       5    12.0   33944.0    25557.0   14925.0  36952.206116    0.5227
# 2       5    21.0   26128.0    17906.0   12233.0  26184.228503    0.9500
# 3       5    12.0   35685.0    20136.0   16250.0  53792.633136    0.5841
# 4       5    43.0   31735.0    16619.0   14112.0  28123.817955    0.4820
#
#    SAT_AVG    UGDS  RET_FT4_POOLED  UGDS_WHITE COST_CATEGORY
# 0   1232.0  1265.0          0.7769      0.7858   Middle cost
# 1   1069.0  2079.0          0.5611      0.4238   Middle cost
# 2      NaN   544.0          0.5000      0.2813   Middle cost
# 3   1100.0  1078.0          0.6602      0.6503   Middle cost
# 4   1054.0   259.0          0.5973      0.6988   Middle cost

# %%
# Check shape
private.shape
# Out:
# (1402, 17)

# %% [markdown]
# # 02. Geospatial Analysis

# %% [markdown]
# ## 01. Number of higher cost institutions

# %%
# Append private onto public to create one large dataframe on which to look at COST_CATEGORY column when doing geospatial analysis
pub_priv = public.append(private)

# %%
# Check shape
pub_priv.shape
# Out:
# (2851, 17)

# %%
# Check output
pub_priv
# Out:
#       UNITID                                               NAME         CITY  \
# 0     100654                           Alabama A & M University       Normal
# 1     100663                University of Alabama at Birmingham   Birmingham
# 2     100706                University of Alabama in Huntsville   Huntsville
# 3     100724                           Alabama State University   Montgomery
# 4     100751                          The University of Alabama   Tuscaloosa
# ...      ...                                                ...          ...
# 1397  491710                       Yeshiva Gedolah of Cliffwood      Keyport
# 1398  491765                              Yeshivas Emek Hatorah       Howell
# 1399  491817                                Seminary Bnos Chaim     Lakewood
# 1400  492801  Drury University-College of Continuing Profess...  Springfield
# 1401  492962  Indiana Institute of Technology-College of Pro...   Fort Wayne
#
#      STATE         ZIP  REGION  LOCALE  COSTT4_A  DEBT_MDN        FAMINC  \
# 0       AL       35762       5    12.0   22489.0   15500.0  32362.826114
# 1       AL  35294-0110       5    12.0   24347.0   15000.0  51306.674306
# 2       AL       35899       5    12.0   23441.0   14476.0  61096.588949
# 3       AL  36104-0271       5    12.0   21476.0   18679.0  31684.382188
# 4       AL  35487-0100       5    12.0   29424.0   17500.0  91846.749624
# ...    ...         ...     ...     ...       ...       ...           ...
# 1397    NJ  07735-5105       2    21.0   14150.0   16500.0  58552.450000
# 1398    NJ  07731-2444       2    21.0   27190.0   16500.0  58552.450000
# 1399    NJ  08701-2336       2    13.0   19886.0   16500.0  58552.450000
# 1400    MO       65802       4    12.0   19707.0   13275.0  58552.450000
# 1401    IN       46803       3    11.0   20329.0   11919.0  58552.450000
#
#       ADM_RATE  SAT_AVG     UGDS  RET_FT4_POOLED  UGDS_WHITE COST_CATEGORY  \
# 0       0.8986    957.0   4990.0          0.5978      0.0186   Higher cost
# 1       0.9211   1220.0  13186.0          0.8303      0.5717   Higher cost
# 2       0.8087   1314.0   7458.0          0.8269      0.7167   Higher cost
# 3       0.9774    972.0   3903.0          0.5898      0.0167   Higher cost
# 4       0.5906   1252.0  32177.0          0.8748      0.7774   Higher cost
# ...        ...      ...      ...             ...         ...           ...
# 1397    0.5854      NaN     84.0          0.9500      1.0000    Lower cost
# 1398       NaN      NaN     46.0          0.7527      1.0000   Middle cost
# 1399    0.8056      NaN    159.0          0.7527      1.0000    Lower cost
# 1400       NaN      NaN   1419.0          0.7568      0.8168    Lower cost
# 1401       NaN      NaN   4456.0          0.5987      0.4165    Lower cost
#
#       NPT4_PRIV
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1397     7150.0
# 1398    20141.0
# 1399    14145.0
# 1400    14368.0
# 1401    14061.0
#
# [2851 rows x 17 columns]

# %%
# Reset index for pub_priv
pub_priv = pub_priv.reset_index(drop=True)

# %%
# Check output
pub_priv
# Out:
#       UNITID                                               NAME         CITY  \
# 0     100654                           Alabama A & M University       Normal
# 1     100663                University of Alabama at Birmingham   Birmingham
# 2     100706                University of Alabama in Huntsville   Huntsville
# 3     100724                           Alabama State University   Montgomery
# 4     100751                          The University of Alabama   Tuscaloosa
# ...      ...                                                ...          ...
# 2846  491710                       Yeshiva Gedolah of Cliffwood      Keyport
# 2847  491765                              Yeshivas Emek Hatorah       Howell
# 2848  491817                                Seminary Bnos Chaim     Lakewood
# 2849  492801  Drury University-College of Continuing Profess...  Springfield
# 2850  492962  Indiana Institute of Technology-College of Pro...   Fort Wayne
#
#      STATE         ZIP  REGION  LOCALE  COSTT4_A  DEBT_MDN        FAMINC  \
# 0       AL       35762       5    12.0   22489.0   15500.0  32362.826114
# 1       AL  35294-0110       5    12.0   24347.0   15000.0  51306.674306
# 2       AL       35899       5    12.0   23441.0   14476.0  61096.588949
# 3       AL  36104-0271       5    12.0   21476.0   18679.0  31684.382188
# 4       AL  35487-0100       5    12.0   29424.0   17500.0  91846.749624
# ...    ...         ...     ...     ...       ...       ...           ...
# 2846    NJ  07735-5105       2    21.0   14150.0   16500.0  58552.450000
# 2847    NJ  07731-2444       2    21.0   27190.0   16500.0  58552.450000
# 2848    NJ  08701-2336       2    13.0   19886.0   16500.0  58552.450000
# 2849    MO       65802       4    12.0   19707.0   13275.0  58552.450000
# 2850    IN       46803       3    11.0   20329.0   11919.0  58552.450000
#
#       ADM_RATE  SAT_AVG     UGDS  RET_FT4_POOLED  UGDS_WHITE COST_CATEGORY  \
# 0       0.8986    957.0   4990.0          0.5978      0.0186   Higher cost
# 1       0.9211   1220.0  13186.0          0.8303      0.5717   Higher cost
# 2       0.8087   1314.0   7458.0          0.8269      0.7167   Higher cost
# 3       0.9774    972.0   3903.0          0.5898      0.0167   Higher cost
# 4       0.5906   1252.0  32177.0          0.8748      0.7774   Higher cost
# ...        ...      ...      ...             ...         ...           ...
# 2846    0.5854      NaN     84.0          0.9500      1.0000    Lower cost
# 2847       NaN      NaN     46.0          0.7527      1.0000   Middle cost
# 2848    0.8056      NaN    159.0          0.7527      1.0000    Lower cost
# 2849       NaN      NaN   1419.0          0.7568      0.8168    Lower cost
# 2850       NaN      NaN   4456.0          0.5987      0.4165    Lower cost
#
#       NPT4_PRIV
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2846     7150.0
# 2847    20141.0
# 2848    14145.0
# 2849    14368.0
# 2850    14061.0
#
# [2851 rows x 17 columns]

# %%
# Drop NPT4_PRIV column
pub_priv = pub_priv.drop(columns = ['NPT4_PRIV'])

# %%
# Check output
pub_priv.head()
# Out:
#    UNITID                                 NAME        CITY STATE         ZIP  \
# 0  100654             Alabama A & M University      Normal    AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham    AL  35294-0110
# 2  100706  University of Alabama in Huntsville  Huntsville    AL       35899
# 3  100724             Alabama State University  Montgomery    AL  36104-0271
# 4  100751            The University of Alabama  Tuscaloosa    AL  35487-0100
#
#    REGION  LOCALE  COSTT4_A  DEBT_MDN        FAMINC  ADM_RATE  SAT_AVG  \
# 0       5    12.0   22489.0   15500.0  32362.826114    0.8986    957.0
# 1       5    12.0   24347.0   15000.0  51306.674306    0.9211   1220.0
# 2       5    12.0   23441.0   14476.0  61096.588949    0.8087   1314.0
# 3       5    12.0   21476.0   18679.0  31684.382188    0.9774    972.0
# 4       5    12.0   29424.0   17500.0  91846.749624    0.5906   1252.0
#
#       UGDS  RET_FT4_POOLED  UGDS_WHITE COST_CATEGORY
# 0   4990.0          0.5978      0.0186   Higher cost
# 1  13186.0          0.8303      0.5717   Higher cost
# 2   7458.0          0.8269      0.7167   Higher cost
# 3   3903.0          0.5898      0.0167   Higher cost
# 4  32177.0          0.8748      0.7774   Higher cost

# %%
# Check value counts for COST_CATEGORY
pub_priv['COST_CATEGORY'].value_counts(dropna = False)
# Out:
# Middle cost    1832
# Higher cost     630
# Lower cost      389
# Name: COST_CATEGORY, dtype: int64

# %%
# Drop missing values
pub_priv = pub_priv[pub_priv['COST_CATEGORY'].notnull()]

# %%
# Check shape
pub_priv.shape
# Out:
# (2851, 16)

# %%
# Check output
pub_priv
# Out:
#       UNITID                                               NAME         CITY  \
# 0     100654                           Alabama A & M University       Normal
# 1     100663                University of Alabama at Birmingham   Birmingham
# 2     100706                University of Alabama in Huntsville   Huntsville
# 3     100724                           Alabama State University   Montgomery
# 4     100751                          The University of Alabama   Tuscaloosa
# ...      ...                                                ...          ...
# 2846  491710                       Yeshiva Gedolah of Cliffwood      Keyport
# 2847  491765                              Yeshivas Emek Hatorah       Howell
# 2848  491817                                Seminary Bnos Chaim     Lakewood
# 2849  492801  Drury University-College of Continuing Profess...  Springfield
# 2850  492962  Indiana Institute of Technology-College of Pro...   Fort Wayne
#
#      STATE         ZIP  REGION  LOCALE  COSTT4_A  DEBT_MDN        FAMINC  \
# 0       AL       35762       5    12.0   22489.0   15500.0  32362.826114
# 1       AL  35294-0110       5    12.0   24347.0   15000.0  51306.674306
# 2       AL       35899       5    12.0   23441.0   14476.0  61096.588949
# 3       AL  36104-0271       5    12.0   21476.0   18679.0  31684.382188
# 4       AL  35487-0100       5    12.0   29424.0   17500.0  91846.749624
# ...    ...         ...     ...     ...       ...       ...           ...
# 2846    NJ  07735-5105       2    21.0   14150.0   16500.0  58552.450000
# 2847    NJ  07731-2444       2    21.0   27190.0   16500.0  58552.450000
# 2848    NJ  08701-2336       2    13.0   19886.0   16500.0  58552.450000
# 2849    MO       65802       4    12.0   19707.0   13275.0  58552.450000
# 2850    IN       46803       3    11.0   20329.0   11919.0  58552.450000
#
#       ADM_RATE  SAT_AVG     UGDS  RET_FT4_POOLED  UGDS_WHITE COST_CATEGORY
# 0       0.8986    957.0   4990.0          0.5978      0.0186   Higher cost
# 1       0.9211   1220.0  13186.0          0.8303      0.5717   Higher cost
# 2       0.8087   1314.0   7458.0          0.8269      0.7167   Higher cost
# 3       0.9774    972.0   3903.0          0.5898      0.0167   Higher cost
# 4       0.5906   1252.0  32177.0          0.8748      0.7774   Higher cost
# ...        ...      ...      ...             ...         ...           ...
# 2846    0.5854      NaN     84.0          0.9500      1.0000    Lower cost
# 2847       NaN      NaN     46.0          0.7527      1.0000   Middle cost
# 2848    0.8056      NaN    159.0          0.7527      1.0000    Lower cost
# 2849       NaN      NaN   1419.0          0.7568      0.8168    Lower cost
# 2850       NaN      NaN   4456.0          0.5987      0.4165    Lower cost
#
# [2851 rows x 16 columns]

# %%
# Get counts of cost category by state
count_cost_cat = pub_priv.groupby(['STATE', 'COST_CATEGORY']).size()

# %%
# Check output
count_cost_cat
# Out:
# STATE  COST_CATEGORY
# AK     Lower cost        2
#        Middle cost       4
# AL     Higher cost       9
#        Lower cost        9
#        Middle cost      22
#                         ..
# WI     Middle cost      51
# WV     Higher cost       3
#        Lower cost        1
#        Middle cost      25
# WY     Middle cost       8
# Length: 151, dtype: int64

# %%
# Turn into data frame
count_cost_cat = count_cost_cat.reset_index()

# %%
# Check output
count_cost_cat
# Out:
#     STATE COST_CATEGORY   0
# 0      AK    Lower cost   2
# 1      AK   Middle cost   4
# 2      AL   Higher cost   9
# 3      AL    Lower cost   9
# 4      AL   Middle cost  22
# ..    ...           ...  ..
# 146    WI   Middle cost  51
# 147    WV   Higher cost   3
# 148    WV    Lower cost   1
# 149    WV   Middle cost  25
# 150    WY   Middle cost   8
#
# [151 rows x 3 columns]

# %%
# Change name of column 0
count_cost_cat.rename(columns = {0 : 'COUNT'}, inplace = True)

# %%
# Check output
count_cost_cat
# Out:
#     STATE COST_CATEGORY  COUNT
# 0      AK    Lower cost      2
# 1      AK   Middle cost      4
# 2      AL   Higher cost      9
# 3      AL    Lower cost      9
# 4      AL   Middle cost     22
# ..    ...           ...    ...
# 146    WI   Middle cost     51
# 147    WV   Higher cost      3
# 148    WV    Lower cost      1
# 149    WV   Middle cost     25
# 150    WY   Middle cost      8
#
# [151 rows x 3 columns]

# %%
# Select higher cost as layer
hist_indicator = 'Higher cost'

# %%
# Create mask for map
mask1 = count_cost_cat['COST_CATEGORY'].str.contains(hist_indicator)

# %%
# Apply mask
stage = count_cost_cat[mask1]

# %%
# Check head
stage.head()
# Out:
#    STATE COST_CATEGORY  COUNT
# 2     AL   Higher cost      9
# 5     AR   Higher cost      7
# 8     AZ   Higher cost      6
# 11    CA   Higher cost     48
# 14    CO   Higher cost     15

# %%
# Create data frame with just states and counts (of higher cost institutions)
data_to_plot = stage[['STATE', 'COUNT']]

# %%
# Check head
data_to_plot.head()
# Out:
#    STATE  COUNT
# 2     AL      9
# 5     AR      7
# 8     AZ      6
# 11    CA     48
# 14    CO     15

# %%
# Look at values for STATE
data_to_plot['STATE'].value_counts(dropna = False)
# Out:
# KY    1
# MD    1
# NC    1
# MS    1
# VA    1
# NY    1
# MN    1
# IA    1
# ME    1
# ID    1
# PA    1
# IN    1
# NH    1
# DE    1
# TX    1
# KS    1
# CA    1
# FL    1
# NJ    1
# WV    1
# NE    1
# WA    1
# UT    1
# MT    1
# ND    1
# CO    1
# TN    1
# OH    1
# MI    1
# OR    1
# LA    1
# WI    1
# NM    1
# HI    1
# AL    1
# IL    1
# MO    1
# AR    1
# AZ    1
# DC    1
# MA    1
# CT    1
# RI    1
# VT    1
# NV    1
# OK    1
# SC    1
# GA    1
# SD    1
# Name: STATE, dtype: int64

# %%
# Setup a folium map at a high-level zoom
map = folium.Map(location = [100,0], zoom_start = 1.5)

# Create the choropleth map
map.choropleth(geo_data = country_geo, data = data_to_plot,
              columns = ['STATE', 'COUNT'],
              key_on = 'feature.id',
              fill_color = 'YlOrBr', fill_opacity = 0.6, line_opacity = 0.1,
              legend_name = 'Number of Higher-cost institutions')
# Out:
# /Users/taraperrigeold/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
# Save map
map.save('plot_data_highcost.html')

# Import the folium interactive HTML file
from IPython.display import HTML
HTML('<iframe src=plot_data_highcost.html width=700 height=450></iframe>')
# Out:
# /Users/taraperrigeold/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=plot_data_highcost.html width=700 height=450></iframe>

# %%
# Check what's up with Alaska
data_to_plot[data_to_plot['STATE'] == 'AK']
# Out:
# Empty DataFrame
# Columns: [STATE, COUNT]
# Index: []

# %%
# Check what's up with Wyoming
data_to_plot[data_to_plot['STATE'] == 'WY']
# Out:
# Empty DataFrame
# Columns: [STATE, COUNT]
# Index: []

# %% [markdown]
# This map shows that Pennsylvania, followed by New York, then California and Massachusetts, have the highest number of 'higher-cost' institutions. There are very few in all the other states, and none in Alaska, Wyoming, and Washington DC.
#
# This map kind of answers one of my research questions. One of them asked whether institutions with higher costs had common characteristics; it does seem as though a handful of states contain the highest concentrations of higher cost institutions. However, it doesn't look like location would be a strong enough indicator for whether an institution is higher cost. It would probably have been better to look at percentage of higher institutions per each state; Pennsylvania, California, New York, Massachusetts, and Texas are likely to have the largest number of higher education institutions and therefore have more higher cost institutions.

# %% [markdown]
# ## 02. Average cost of attendance at public institutions

# %%
# Check for missing values of COSTT4_A for public institutions
public['COSTT4_A'].isnull().sum()
# Out:
# 0

# %%
# Create dataframe of just STATE and COSTT4_A
pub_cost = public[['STATE', 'COSTT4_A']]

# %%
# Check output
pub_cost.head()
# Out:
#   STATE  COSTT4_A
# 0    AL   22489.0
# 1    AL   24347.0
# 2    AL   23441.0
# 3    AL   21476.0
# 4    AL   29424.0

# %%
# Get average of COSTT4_A for each state
pub_cost_avg = pub_cost.groupby('STATE').agg({'COSTT4_A':'mean'})

# %%
# Check output
pub_cost_avg
# Out:
#            COSTT4_A
# STATE
# AK     18435.000000
# AL     17251.280000
# AR     15299.620690
# AZ     15590.565217
# CA     15440.371212
# CO     19799.703704
# CT     16488.800000
# DC     22928.000000
# DE     17808.500000
# FL     14148.891892
# GA     15096.837209
# GU     13659.000000
# HI     15871.900000
# IA     15947.809524
# ID     15785.375000
# IL     13821.438596
# IN     18698.214286
# KS     14811.531250
# KY     14924.166667
# LA     17052.714286
# MA     18495.370370
# MD     17830.880000
# ME     17043.666667
# MI     14868.146341
# MN     17457.976190
# MO     15971.214286
# MS     15706.000000
# MT     15749.583333
# NC     14946.229167
# ND     16343.090909
# NE     16546.214286
# NH     21837.636364
# NJ     19006.517241
# NM     13573.800000
# NV     15715.857143
# NY     17379.358974
# OH     14852.450000
# OK     16009.111111
# OR     16474.920000
# PA     22741.964912
# PR     11857.363636
# RI     19002.000000
# SC     18895.466667
# SD     19685.300000
# TN     16830.350000
# TX     14692.771739
# UT     16213.875000
# VA     19124.451613
# VI     17349.000000
# VT     24438.600000
# WA     15030.853659
# WI     16252.068966
# WV     15121.476190
# WY     13114.625000

# %%
# Reset index
pub_cost_avg = pub_cost_avg.reset_index()

# %%
# Check output
pub_cost_avg.head()
# Out:
#   STATE      COSTT4_A
# 0    AK  18435.000000
# 1    AL  17251.280000
# 2    AR  15299.620690
# 3    AZ  15590.565217
# 4    CA  15440.371212

# %%
# Check values in STATE column
pub_cost_avg['STATE'].value_counts(dropna=False)
# Out:
# SC    1
# PR    1
# TX    1
# HI    1
# AL    1
# NE    1
# ID    1
# AR    1
# LA    1
# RI    1
# OK    1
# GA    1
# ND    1
# MT    1
# DC    1
# WI    1
# VA    1
# NM    1
# AZ    1
# ME    1
# NC    1
# CT    1
# NH    1
# VT    1
# CA    1
# MN    1
# MI    1
# SD    1
# CO    1
# KY    1
# OR    1
# PA    1
# IL    1
# MO    1
# TN    1
# VI    1
# OH    1
# WV    1
# MA    1
# AK    1
# MD    1
# MS    1
# NY    1
# IN    1
# IA    1
# DE    1
# KS    1
# NV    1
# GU    1
# FL    1
# NJ    1
# WY    1
# UT    1
# WA    1
# Name: STATE, dtype: int64

# %%
# Remove rows for US territories: GU
pub_cost_avg = pub_cost_avg[pub_cost_avg['STATE'] != 'GU']

# %%
# Remove rows for US territories: PR
pub_cost_avg = pub_cost_avg[pub_cost_avg['STATE'] != 'PR']

# %%
# Remove rows for US territories: VI
pub_cost_avg = pub_cost_avg[pub_cost_avg['STATE'] != 'VI']

# %%
# Check shape
pub_cost_avg.shape
# Out:
# (51, 2)

# %%
# Set up folium map at high-level zoom
map2 = folium.Map(location = [100,0], zoom_start = 1.5)

# Create choropleth map
map2.choropleth(geo_data = country_geo, data = pub_cost_avg,
              columns = ['STATE', 'COSTT4_A'],
              key_on = 'feature.id',
              fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
              legend_name = 'Average cost of public institutions')
# Out:
# /Users/taraperrigeold/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
# Save map
map2.save('plot_data_pub_avgcost.html')

# Import the Folium interactive html file
from IPython.display import HTML
HTML('<iframe src=plot_data_pub_avgcost.html width=700 height=450></iframe>')
# Out:
# /Users/taraperrigeold/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=plot_data_pub_avgcost.html width=700 height=450></iframe>

# %% [markdown]
# This map shows that states with the highest average costs for public institutions are Vermont and Pennsylvania. This leads me to wonder why the public colleges in those specific states are a lot more expensive. One theory is that they enroll more out-of-state students, who have to pay much higher tuition than in-state students, and therefore push the average cost of attendance higher.
#
# This is also related to my research question of whether institutions with higher costs have common characteristics. I could look further into whether the institutions from the states listed above have other common characteristics.

# %% [markdown]
# ## 03. Average cost of attendance at private institutions

# %%
# Check for missing values of COSTT4_A for private institutions
private['COSTT4_A'].isnull().sum()
# Out:
# 0

# %%
# Create dataframe of just STATE and COSTT4_A
priv_cost = private[['STATE', 'COSTT4_A']]

# %%
# Check output
priv_cost
# Out:
#      STATE  COSTT4_A
# 0       AL   52176.0
# 1       AL   33944.0
# 2       AL   26128.0
# 3       AL   35685.0
# 4       AL   31735.0
# ...    ...       ...
# 1397    NJ   14150.0
# 1398    NJ   27190.0
# 1399    NJ   19886.0
# 1400    MO   19707.0
# 1401    IN   20329.0
#
# [1402 rows x 2 columns]

# %%
# Get average of COSTT4_A for each state
priv_cost_avg = priv_cost.groupby('STATE').agg({'COSTT4_A':'mean'})

# %%
# Check output
priv_cost_avg
# Out:
#            COSTT4_A
# STATE
# AK     26788.666667
# AL     33139.866667
# AR     30917.066667
# AZ     37335.500000
# CA     45712.595745
# CO     45615.400000
# CT     54050.266667
# DC     49278.500000
# DE     35213.750000
# FL     35802.877193
# GA     37227.000000
# GU     11151.000000
# HI     28039.600000
# IA     42433.900000
# ID     33922.600000
# IL     42295.519231
# IN     41382.638889
# KS     36695.333333
# KY     36352.652174
# LA     34928.785714
# MA     54053.508197
# MD     47444.647059
# ME     47738.250000
# MI     39200.700000
# MN     43151.785714
# MO     34386.926829
# MS     27526.875000
# MT     29977.400000
# NC     40748.047619
# ND     22698.600000
# NE     34179.733333
# NH     49434.555556
# NJ     34004.750000
# NM     45676.000000
# NV     37418.666667
# NY     38083.354839
# OH     38883.536232
# OK     35449.714286
# OR     45289.444444
# PA     45294.819048
# PR     14423.658537
# RI     55448.888889
# SC     36768.130435
# SD     35421.333333
# TN     35989.555556
# TX     36202.105263
# UT     30728.000000
# VA     42619.322581
# VT     53700.083333
# WA     44144.000000
# WI     41001.285714
# WV     37871.375000

# %%
# Reset index
priv_cost_avg = priv_cost_avg.reset_index()

# %%
# Check output
priv_cost_avg.head()
# Out:
#   STATE      COSTT4_A
# 0    AK  26788.666667
# 1    AL  33139.866667
# 2    AR  30917.066667
# 3    AZ  37335.500000
# 4    CA  45712.595745

# %%
# Check values for STATE column
priv_cost_avg['STATE'].value_counts(dropna = False)
# Out:
# SC    1
# DC    1
# HI    1
# AL    1
# NE    1
# ID    1
# AR    1
# LA    1
# RI    1
# OK    1
# GA    1
# ND    1
# PR    1
# MT    1
# WI    1
# VA    1
# NM    1
# AZ    1
# ME    1
# NC    1
# CT    1
# NH    1
# VT    1
# CA    1
# MN    1
# TX    1
# MI    1
# SD    1
# MS    1
# OR    1
# PA    1
# IL    1
# MO    1
# TN    1
# OH    1
# WV    1
# MA    1
# AK    1
# MD    1
# NY    1
# CO    1
# IN    1
# IA    1
# DE    1
# KS    1
# NV    1
# GU    1
# FL    1
# NJ    1
# UT    1
# KY    1
# WA    1
# Name: STATE, dtype: int64

# %%
# Remove rows for US territories: PR
priv_cost_avg = priv_cost_avg[priv_cost_avg['STATE'] != 'PR']

# %%
# Remove rows for US territories: GU
priv_cost_avg = priv_cost_avg[priv_cost_avg['STATE'] != 'GU']

# %%
# Check shape
priv_cost_avg.shape
# Out:
# (50, 2)

# %%
# Set up folium map at high-level zoom
map3 = folium.Map(location = [100,0], zoom_start = 1.5)

# Create choropleth map
map3.choropleth(geo_data = country_geo, data = priv_cost_avg,
              columns = ['STATE', 'COSTT4_A'],
              key_on = 'feature.id',
              fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
              legend_name = 'Average cost of private institutions')
# Out:
# /Users/taraperrigeold/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
# Save map
map3.save('plot_data_priv_avgcost.html')

# Import the Folium interactive html file
from IPython.display import HTML
HTML('<iframe src=plot_data_priv_avgcost.html width=700 height=450></iframe>')
# Out:
# /Users/taraperrigeold/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=plot_data_priv_avgcost.html width=700 height=450></iframe>

# %%
# Chck what's going on with Wyoming
priv_cost[priv_cost['STATE'] == 'WY']
# Out:
# Empty DataFrame
# Columns: [STATE, COSTT4_A]
# Index: []

# %% [markdown]
# This map shows that the states with the highest average costs for private institutions are Vermont, Massachusetts and Connecticut (with no data for Wyoming). Curiously enough, Vermont also had high average costs for its public institutions. This makes me wonder why the institutions in these states have higher average costs. Since these are private colleges, are the ones in these states a lot more selective than in other states? Or maybe it's related to cost of living in these states, and costs are higher because salaries and expenses having to do with various facilities are much higher (including taxes on land, although that is definitely outside of the scope of my data).
#
# This also has to do with my research question concerning common characteristics of higher cost institutions. I could look further into whether the institutions from the states listed above have other common characteristics.

# %% [markdown]
# ## 04. Average family income

# %%
# Append private onto public to create one large dataframe on which to look at family income when doing geospatial analysis
pub_priv2 = public.append(private)

# %%
# Check output
pub_priv2
# Out:
#       UNITID                                               NAME         CITY  \
# 0     100654                           Alabama A & M University       Normal
# 1     100663                University of Alabama at Birmingham   Birmingham
# 2     100706                University of Alabama in Huntsville   Huntsville
# 3     100724                           Alabama State University   Montgomery
# 4     100751                          The University of Alabama   Tuscaloosa
# ...      ...                                                ...          ...
# 1397  491710                       Yeshiva Gedolah of Cliffwood      Keyport
# 1398  491765                              Yeshivas Emek Hatorah       Howell
# 1399  491817                                Seminary Bnos Chaim     Lakewood
# 1400  492801  Drury University-College of Continuing Profess...  Springfield
# 1401  492962  Indiana Institute of Technology-College of Pro...   Fort Wayne
#
#      STATE         ZIP  REGION  LOCALE  COSTT4_A  DEBT_MDN        FAMINC  \
# 0       AL       35762       5    12.0   22489.0   15500.0  32362.826114
# 1       AL  35294-0110       5    12.0   24347.0   15000.0  51306.674306
# 2       AL       35899       5    12.0   23441.0   14476.0  61096.588949
# 3       AL  36104-0271       5    12.0   21476.0   18679.0  31684.382188
# 4       AL  35487-0100       5    12.0   29424.0   17500.0  91846.749624
# ...    ...         ...     ...     ...       ...       ...           ...
# 1397    NJ  07735-5105       2    21.0   14150.0   16500.0  58552.450000
# 1398    NJ  07731-2444       2    21.0   27190.0   16500.0  58552.450000
# 1399    NJ  08701-2336       2    13.0   19886.0   16500.0  58552.450000
# 1400    MO       65802       4    12.0   19707.0   13275.0  58552.450000
# 1401    IN       46803       3    11.0   20329.0   11919.0  58552.450000
#
#       ADM_RATE  SAT_AVG     UGDS  RET_FT4_POOLED  UGDS_WHITE COST_CATEGORY  \
# 0       0.8986    957.0   4990.0          0.5978      0.0186   Higher cost
# 1       0.9211   1220.0  13186.0          0.8303      0.5717   Higher cost
# 2       0.8087   1314.0   7458.0          0.8269      0.7167   Higher cost
# 3       0.9774    972.0   3903.0          0.5898      0.0167   Higher cost
# 4       0.5906   1252.0  32177.0          0.8748      0.7774   Higher cost
# ...        ...      ...      ...             ...         ...           ...
# 1397    0.5854      NaN     84.0          0.9500      1.0000    Lower cost
# 1398       NaN      NaN     46.0          0.7527      1.0000   Middle cost
# 1399    0.8056      NaN    159.0          0.7527      1.0000    Lower cost
# 1400       NaN      NaN   1419.0          0.7568      0.8168    Lower cost
# 1401       NaN      NaN   4456.0          0.5987      0.4165    Lower cost
#
#       NPT4_PRIV
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1397     7150.0
# 1398    20141.0
# 1399    14145.0
# 1400    14368.0
# 1401    14061.0
#
# [2851 rows x 17 columns]

# %%
# Reset index
pub_priv2 = pub_priv2.reset_index(drop=True)

# %%
# Check output
pub_priv2
# Out:
#       UNITID                                               NAME         CITY  \
# 0     100654                           Alabama A & M University       Normal
# 1     100663                University of Alabama at Birmingham   Birmingham
# 2     100706                University of Alabama in Huntsville   Huntsville
# 3     100724                           Alabama State University   Montgomery
# 4     100751                          The University of Alabama   Tuscaloosa
# ...      ...                                                ...          ...
# 2846  491710                       Yeshiva Gedolah of Cliffwood      Keyport
# 2847  491765                              Yeshivas Emek Hatorah       Howell
# 2848  491817                                Seminary Bnos Chaim     Lakewood
# 2849  492801  Drury University-College of Continuing Profess...  Springfield
# 2850  492962  Indiana Institute of Technology-College of Pro...   Fort Wayne
#
#      STATE         ZIP  REGION  LOCALE  COSTT4_A  DEBT_MDN        FAMINC  \
# 0       AL       35762       5    12.0   22489.0   15500.0  32362.826114
# 1       AL  35294-0110       5    12.0   24347.0   15000.0  51306.674306
# 2       AL       35899       5    12.0   23441.0   14476.0  61096.588949
# 3       AL  36104-0271       5    12.0   21476.0   18679.0  31684.382188
# 4       AL  35487-0100       5    12.0   29424.0   17500.0  91846.749624
# ...    ...         ...     ...     ...       ...       ...           ...
# 2846    NJ  07735-5105       2    21.0   14150.0   16500.0  58552.450000
# 2847    NJ  07731-2444       2    21.0   27190.0   16500.0  58552.450000
# 2848    NJ  08701-2336       2    13.0   19886.0   16500.0  58552.450000
# 2849    MO       65802       4    12.0   19707.0   13275.0  58552.450000
# 2850    IN       46803       3    11.0   20329.0   11919.0  58552.450000
#
#       ADM_RATE  SAT_AVG     UGDS  RET_FT4_POOLED  UGDS_WHITE COST_CATEGORY  \
# 0       0.8986    957.0   4990.0          0.5978      0.0186   Higher cost
# 1       0.9211   1220.0  13186.0          0.8303      0.5717   Higher cost
# 2       0.8087   1314.0   7458.0          0.8269      0.7167   Higher cost
# 3       0.9774    972.0   3903.0          0.5898      0.0167   Higher cost
# 4       0.5906   1252.0  32177.0          0.8748      0.7774   Higher cost
# ...        ...      ...      ...             ...         ...           ...
# 2846    0.5854      NaN     84.0          0.9500      1.0000    Lower cost
# 2847       NaN      NaN     46.0          0.7527      1.0000   Middle cost
# 2848    0.8056      NaN    159.0          0.7527      1.0000    Lower cost
# 2849       NaN      NaN   1419.0          0.7568      0.8168    Lower cost
# 2850       NaN      NaN   4456.0          0.5987      0.4165    Lower cost
#
#       NPT4_PRIV
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2846     7150.0
# 2847    20141.0
# 2848    14145.0
# 2849    14368.0
# 2850    14061.0
#
# [2851 rows x 17 columns]

# %%
# Check shape
pub_priv2.shape
# Out:
# (2851, 17)

# %%
# Drop NPT4_PRIV column
pub_priv2 = pub_priv2.drop(columns = ['NPT4_PRIV'])

# %%
# Check for missing values for family income
pub_priv2['FAMINC'].isnull().sum()
# Out:
# 0

# %%
# Create data frame with just states and average family income
avg_faminc = pub_priv2[['STATE', 'FAMINC']]

# %%
# Check output
avg_faminc
# Out:
#      STATE        FAMINC
# 0       AL  32362.826114
# 1       AL  51306.674306
# 2       AL  61096.588949
# 3       AL  31684.382188
# 4       AL  91846.749624
# ...    ...           ...
# 2846    NJ  58552.450000
# 2847    NJ  58552.450000
# 2848    NJ  58552.450000
# 2849    MO  58552.450000
# 2850    IN  58552.450000
#
# [2851 rows x 2 columns]

# %%
# Get average of FAMINC for each state
avg_faminc_agg = avg_faminc.groupby('STATE').agg({'FAMINC':'mean'})

# %%
# Check output
avg_faminc_agg
# Out:
#              FAMINC
# STATE
# AK     43016.561668
# AL     45094.289108
# AR     38740.143545
# AZ     37321.404426
# CA     39442.840757
# CO     52171.221491
# CT     64443.354356
# DC     71693.499163
# DE     50260.252741
# FL     41220.373870
# GA     44958.272447
# GU     20077.400983
# HI     37186.418418
# IA     60040.419321
# ID     44580.808757
# IL     49078.232744
# IN     66960.218906
# KS     49688.012299
# KY     44054.746801
# LA     41145.221834
# MA     71837.662044
# MD     60122.052789
# ME     59165.535453
# MI     52051.838963
# MN     59498.694843
# MO     52514.044519
# MS     35976.023791
# MT     50562.619489
# NC     46240.513703
# ND     61205.120129
# NE     60531.600275
# NH     72463.617420
# NJ     53125.948839
# NM     35885.931690
# NV     38240.225589
# NY     54753.317453
# OH     60656.686063
# OK     45231.204748
# OR     52586.471192
# PA     70974.701109
# PR     15275.915615
# RI     88249.442971
# SC     49626.442539
# SD     63596.869882
# TN     49419.641928
# TX     41899.206441
# UT     39706.212556
# VA     61626.347908
# VI     31398.638526
# VT     73062.923215
# WA     45563.399950
# WI     59949.715643
# WV     49460.163978
# WY     45589.271447

# %%
# Reset index
avg_faminc_agg = avg_faminc_agg.reset_index()

# %%
# Check output
avg_faminc_agg.head()
# Out:
#   STATE        FAMINC
# 0    AK  43016.561668
# 1    AL  45094.289108
# 2    AR  38740.143545
# 3    AZ  37321.404426
# 4    CA  39442.840757

# %%
# Check values for STATE column
avg_faminc_agg['STATE'].value_counts(dropna = False)
# Out:
# SC    1
# PR    1
# TX    1
# HI    1
# AL    1
# NE    1
# ID    1
# AR    1
# LA    1
# RI    1
# OK    1
# GA    1
# ND    1
# MT    1
# DC    1
# WI    1
# VA    1
# NM    1
# AZ    1
# ME    1
# NC    1
# CT    1
# NH    1
# VT    1
# CA    1
# MN    1
# MI    1
# SD    1
# CO    1
# KY    1
# OR    1
# PA    1
# IL    1
# MO    1
# TN    1
# VI    1
# OH    1
# WV    1
# MA    1
# AK    1
# MD    1
# MS    1
# NY    1
# IN    1
# IA    1
# DE    1
# KS    1
# NV    1
# GU    1
# FL    1
# NJ    1
# WY    1
# UT    1
# WA    1
# Name: STATE, dtype: int64

# %%
# Remove rows for US territories: PR
avg_faminc_agg = avg_faminc_agg[avg_faminc_agg['STATE'] != 'PR']

# %%
# Remove rows for US territories: VI
avg_faminc_agg = avg_faminc_agg[avg_faminc_agg['STATE'] != 'VI']

# %%
# Remove rows for US territories: GU
avg_faminc_agg = avg_faminc_agg[avg_faminc_agg['STATE'] != 'GU']

# %%
# Check shape
avg_faminc_agg.shape
# Out:
# (51, 2)

# %%
# Set up folium map at high-level zoom
map4 = folium.Map(location = [100,0], zoom_start = 1.5)

# Create choropleth map
map4.choropleth(geo_data = country_geo, data = avg_faminc_agg,
              columns = ['STATE', 'FAMINC'],
              key_on = 'feature.id',
              fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
              legend_name = 'Average family income of students')
# Out:
# /Users/taraperrigeold/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
# Save map
map4.save('plot_data_avg_faminc.html')

# Import the Folium interactive html file
from IPython.display import HTML
HTML('<iframe src=plot_data_avg_faminc.html width=700 height=450></iframe>')
# Out:
# /Users/taraperrigeold/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=plot_data_avg_faminc.html width=700 height=450></iframe>

# %% [markdown]
# This map shows that the following states have the highest average family incomes for students enrolled in institutions there: Vermont, New Hampshire, Massachusetts, Rhode Island, and Pennsylvania. There is some overlap here with states with higher average costs: Vermont (public & private), Massachusetts (private), New Mexico (private), and Pennsylvania (public). First of all, South Dakota seems odd to me; however, it's possible that young people tend to not go to college in South Dakota unless their family is more well-off. One way to tell would probably be to look at percentage of young people who go to college, which is outside the scope of my data. As for Vermont and Massachusetts, this probably lends credence to my thought earlier that these states have higher costs of living, considering incomes there tend to be higher. However, I know for a fact that California and Washington have extremely high costs of living, but average family incomes of college students don't seem to be at the highest end of the spectrum. So while that might be one aspect of it, it's certainly not the only reason. It could also have to do with inequality; for example, California and Massachusetts might both have very high costs of living, but California might have a lot more inequality (spread between lowest and highest incomes) compared to Massachusetts (where the lowest incomes might be closer to the highest incomes). However, my data set does not include anything about equality or inequality between states.
